# %%
# Proje 1. Kısım

# %%
def flat_gen(list1):
    if type(list1) is list:
        for i in list1:
            yield from flat_gen(i)
    else:
        yield list1

def flatten(list1):
    return list(flat_gen(list1))

list1 = [[1,'a',['cat'],2],[[[3]],'dog'],4,5]
flat_list = flatten(list1)
print(flat_list)
# Out:
# [1, 'a', 'cat', 2, 3, 'dog', 4, 5]

# %%
#Proje 2. Kısım

# %%
L1=[1, 2]
L2=[3, 4]
L3=[5, 6, 7]
list=[L1, L2, L3]
list
# Out:
# [[1, 2], [3, 4], [5, 6, 7]]

# %%
L1.reverse()
L2.reverse()
L3.reverse()
list.reverse()
list
# Out:
# [[7, 6, 5], [4, 3], [2, 1]]
